# %%
from qiskit import *
from qiskit.tools.visualization import plot_bloch_multivector, array_to_latex
from math import pi
# %matplotlib inline

# %%
circuit = QuantumCircuit(1)
circuit.ry(pi/4, 0)
circuit.x(0) #rotating 180 degree around the X-axis
#circuit.x(0)#second gate to put it into superposition 
print(circuit)
circuit.draw(output='mpl')
# Out:
#    ┌─────────┐┌───┐
# q: ┤ Ry(π/4) ├┤ X ├
#    └─────────┘└───┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector, prefix="\\text{statevector = }\n")
# Out:
# $$
# \text{statevector = }
#
# \begin{bmatrix}
# 0.3826834324 & 0.9238795325  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(statevector)
