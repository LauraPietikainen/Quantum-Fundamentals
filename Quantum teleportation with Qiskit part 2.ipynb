# %%
from qiskit import *
from qiskit.tools.visualization import plot_bloch_multivector, plot_histogram
from math import pi
# %matplotlib inline

# %%
# initialize 3-qubit circuit with named registers
q0 = QuantumRegister(1, name="q0") # source qubit to teleport
q1 = QuantumRegister(1, name="q1") # middle qubit(half of Bell state pair)
q2 = QuantumRegister(1, name="q2") # destination qubit (half of Bell state pair)

crz = ClassicalRegister(1, name="crz") # measurement of the source qubit
crx = ClassicalRegister(1, name="crx") # measurement of middle qubit (half of Bell state pair)

circuit = QuantumCircuit(q0, q1, q2, crz, crx)

# initialize qubit (quantum state to teleport)
circuit.x(0)
circuit.barrier()

# create Bell state pair
circuit.h(q1)
circuit.cx(q1, q2)
circuit.barrier()

# performs Bell state measurement
circuit.cx(q0, q1)
circuit.h(q0)
circuit.barrier()
circuit.measure(q0, crz)
circuit.measure(q1, crx)
circuit.barrier()

# transforms qubit based on measurement results
circuit.x(q2).c_if(crx, 1)  # apply X gate if cr_x is 1
circuit.z(q2).c_if(crz, 1)  # apply Z gate if cr_z is 1

circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
statevector = execute(circuit, backend=simulator).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
# add final measurement 
cr_result = ClassicalRegister(1, name="result")
circuit.barrier()
circuit.add_register(cr_result)
circuit.measure(2, 2)
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator).result()
plot_histogram(result.get_counts())

# %%
# quantum teleportation circuit using deferred measurement
circuit_def = QuantumCircuit(3, 1)

# initialize (quantum state to teleport)
circuit_def.x(0)
circuit_def.barrier()

# create Bell state pair
circuit_def.h(1)
circuit_def.cx(1, 2)
circuit_def.barrier()

# Performs Bell state measurement
circuit_def.cx(0, 1)
circuit_def.h(0)
circuit_def.barrier()

# apply conditional operations 
circuit_def.cx(1, 2)
circuit_def.cz(0, 2)
circuit_def.barrier()

# measure destination qubit
circuit_def.measure(2, 0)

circuit_def.draw(output='mpl')

# %%
result_def = execute(circuit_def, backend=simulator).result()
plot_histogram(result_def.get_counts())
